# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import inspect, create_engine, func

# %%
# create engine to hawaii.sqlite
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# View all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
Base.classes.measurement
# Out:
# sqlalchemy.ext.automap.measurement

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %%
inspector=inspect(engine)
inspector.get_table_names()
# Out:
# ['measurement', 'station']

# %%
columns_meas = inspector.get_columns('measurement')

# %%
columns_meas
# Out:
# [{'name': 'id',
#   'type': INTEGER(),
#   'nullable': False,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 1},
#  {'name': 'station',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'date',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'prcp',
#   'type': FLOAT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'tobs',
#   'type': FLOAT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0}]

# %%
for col in columns_meas:
    print(col['name'],col['type'])
# Out:
# id INTEGER
# station TEXT
# date TEXT
# prcp FLOAT
# tobs FLOAT

# %%
session.query(Measurement.date).limit(10).all()
# Out:
# [('2010-01-01'),
#  ('2010-01-02'),
#  ('2010-01-03'),
#  ('2010-01-04'),
#  ('2010-01-06'),
#  ('2010-01-07'),
#  ('2010-01-08'),
#  ('2010-01-09'),
#  ('2010-01-10'),
#  ('2010-01-11')]

# %%
session.query(Measurement.station).limit(10).all()
# Out:
# [('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397')]

# %%
session.query(Measurement.tobs).limit(10).all()
# Out:
# [(65.0),
#  (63.0),
#  (74.0),
#  (76.0),
#  (73.0),
#  (70.0),
#  (64.0),
#  (68.0),
#  (73.0),
#  (64.0)]

# %%
columns_stat = inspector.get_columns('station')
columns_stat
# Out:
# [{'name': 'id',
#   'type': INTEGER(),
#   'nullable': False,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 1},
#  {'name': 'station',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'name',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'latitude',
#   'type': FLOAT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'longitude',
#   'type': FLOAT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'elevation',
#   'type': FLOAT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0}]

# %%
for col in columns_stat:
    print(col['name'],col['type'])
# Out:
# id INTEGER
# station TEXT
# name TEXT
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %%
session.query(Station.name).limit(10).all()
# Out:
# [('WAIKIKI 717.2, HI US'),
#  ('KANEOHE 838.1, HI US'),
#  ('KUALOA RANCH HEADQUARTERS 886.9, HI US'),
#  ('PEARL CITY, HI US'),
#  ('UPPER WAHIAWA 874.3, HI US'),
#  ('WAIMANALO EXPERIMENTAL FARM, HI US'),
#  ('WAIHEE 837.5, HI US'),
#  ('HONOLULU OBSERVATORY 702.2, HI US'),
#  ('MANOA LYON ARBO 785.2, HI US')]

# %%
session.query(Station.station).limit(10).all()
# Out:
# [('USC00519397'),
#  ('USC00513117'),
#  ('USC00514830'),
#  ('USC00517948'),
#  ('USC00518838'),
#  ('USC00519523'),
#  ('USC00519281'),
#  ('USC00511918'),
#  ('USC00516128')]

# %% [markdown]
# # Exploratory Precipitation Analysis

# %%
# Find the most recent date in the data set.
most_recent_date = session.query(func.max(Measurement.date)).first()
most_recent_date
# Out:
# ('2017-08-23')

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results. 
# Starting from the most recent data point in the database. 

# Calculate the date one year from the last date in data set.
prev_year = dt.date(2017, 8, 23) - dt.timedelta(days=365)
prev_year
# Out:
# datetime.date(2016, 8, 23)

# %%
# Perform a query to retrieve the data and precipitation scores
results = session.query(Measurement.date, Measurement.prcp).filter(Measurement.date >= prev_year).all()
results
# Out:
# [('2016-08-23', 0.0),
#  ('2016-08-24', 0.08),
#  ('2016-08-25', 0.08),
#  ('2016-08-26', 0.0),
#  ('2016-08-27', 0.0),
#  ('2016-08-28', 0.01),
#  ('2016-08-29', 0.0),
#  ('2016-08-30', 0.0),
#  ('2016-08-31', 0.13),
#  ('2016-09-01', 0.0),
#  ('2016-09-02', 0.0),
#  ('2016-09-03', 0.0),
#  ('2016-09-04', 0.03),
#  ('2016-09-05', None),
#  ('2016-09-06', None),
#  ('2016-09-07', 0.05),
#  ('2016-09-08', 0.0),
#  ('2016-09-09', 0.03),
#  ('2016-09-10', 0.0),
#  ('2016-09-11', 0.05),
#  ('2016-09-12', 0.0),
#  ('2016-09-13', 0.02),
#  ('2016-09-14', 1.32),
#  ('2016-09-15', 0.42),
#  ('2016-09-16', 0.06),
#  ('2016-09-17', 0.05),
#  ('2016-09-18', 0.0),
#  ('2016-09-19', 0.0),
#  ('2016-09-20', 0.0),
#  ('2016-09-21', 0.0),
#  ('2016-09-22', 0.02),
#  ('2016-09-23', 0.0),
#  ('2016-09-24', 0.0),
#  ('2016-09-25', 0.0),
#  ('2016-09-26', 0.06),
#  ('2016-09-27', 0.02),
#  ('2016-09-28', 0.0),
#  ('2016-09-29', 0.0),
#  ('2016-09-30', 0.0),
#  ('2016-10-01', 0.0),
# ...

# %%
# Save the query results as a Pandas DataFrame
precip_df = pd.DataFrame(results)
precip_df
# Out:
#             date  prcp
# 0     2016-08-23  0.00
# 1     2016-08-24  0.08
# 2     2016-08-25  0.08
# 3     2016-08-26  0.00
# 4     2016-08-27  0.00
# ...          ...   ...
# 2225  2017-08-19  0.09
# 2226  2017-08-20   NaN
# 2227  2017-08-21  0.56
# 2228  2017-08-22  0.50
# 2229  2017-08-23  0.45
#
# [2230 rows x 2 columns]

# %%
# Set the index to the date column
precip_date_index_df = precip_df.set_index('date')
precip_date_index_df
# Out:
#             prcp
# date
# 2016-08-23  0.00
# 2016-08-24  0.08
# 2016-08-25  0.08
# 2016-08-26  0.00
# 2016-08-27  0.00
# ...          ...
# 2017-08-19  0.09
# 2017-08-20   NaN
# 2017-08-21  0.56
# 2017-08-22  0.50
# 2017-08-23  0.45
#
# [2230 rows x 1 columns]

# %%
# Sort the dataframe by date and rename 'prcp' column to 'precipitation'
precip_by_date_df = precip_date_index_df.sort_index(ascending=True)
precip_by_date_df = precip_by_date_df.rename(columns={'prcp' : 'precipitation'})
precip_by_date_df
# Out:
#             precipitation
# date
# 2016-08-23           0.00
# 2016-08-23            NaN
# 2016-08-23           1.79
# 2016-08-23           0.05
# 2016-08-23           0.15
# ...                   ...
# 2017-08-22           0.00
# 2017-08-23           0.00
# 2017-08-23           0.00
# 2017-08-23           0.08
# 2017-08-23           0.45
#
# [2230 rows x 1 columns]

# %%
# Plot the results using the DataFrame plot method
precip_by_date_df.plot(figsize=(10,6), rot=90)
plt.legend(loc='upper right')
plt.xlabel("Date")
plt.ylabel("Inches")
# plt.locator_paramas(axis="x", nbins=9)
plt.show()

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data
precip_by_date_df.describe()
# Out:
#        precipitation
# count    2021.000000
# mean        0.177279
# std         0.461190
# min         0.000000
# 25%         0.000000
# 50%         0.020000
# 75%         0.130000
# max         6.700000

# %% [markdown]
# # Exploratory Station Analysis

# %%
# Design a query to calculate the total number stations in the dataset
stations_total = session.query(Station).count()
print(f"Total number of stations: {stations_total}")
# Out:
# Total number of stations: 9

# %%
# Design a query to find the most active stations (i.e. what stations have the most rows?)
# List the stations and the counts in descending order.
station_activity = (session.query(Measurement.station, func.count(Measurement.station))
                        .group_by(Measurement.station)
                        .order_by(func.count(Measurement.station).desc())
                        .all())
station_activity
# Out:
# [('USC00519281', 2772),
#  ('USC00519397', 2724),
#  ('USC00513117', 2709),
#  ('USC00519523', 2669),
#  ('USC00516128', 2612),
#  ('USC00514830', 2202),
#  ('USC00511918', 1979),
#  ('USC00517948', 1372),
#  ('USC00518838', 511)]

# %%
# Using the most active station id from the previous query, calculate the lowest, highest, and average temperature.

# Get the ID of the most active station
active_station_ID = station_activity[0][0]

# Get the name of the most active station
active_stationName = (session.query(Station.name)
                      .filter_by(station = most_active_station))
active_stationName = active_stationName[0][0]

print(f"The most active station is: '{active_stationName}' (ID: {active_station_ID})")
# Out:
# The most active station is: 'WAIHEE 837.5, HI US' (ID: USC00519281)

# %%
# Calculate the lowest temperate at Waihee
lowest_temp = (session.query(Measurement.tobs).
               filter(Measurement.station == active_station_ID).
               order_by(Measurement.tobs.asc()).
               first())
lowest_temp = lowest_temp[0]
print(f"The lowest temperature at '{active_stationName}' is {lowest_temp} degrees Farenheit.")
# Out:
# The lowest temperature at 'WAIHEE 837.5, HI US' is 54.0 degrees Farenheit.

# %%
# Calculate the highest temperate at Waihee
highest_temp = (session.query(Measurement.tobs).
               filter(Measurement.station == active_station_ID).
               order_by(Measurement.tobs.desc()).
               first())
highest_temp = highest_temp[0]
print(f"The lowest temperature at '{active_stationName}' is {highest_temp} degrees Farenheit.")
# Out:
# The lowest temperature at 'WAIHEE 837.5, HI US' is 85.0 degrees Farenheit.

# %%
# Calculate the highest temperate at Waihee
av_temp = (session.query(func.avg(Measurement.tobs))
                  .filter(Measurement.station == active_station_ID))
av_temp = '{0:.3}'.format(av_temp[0][0])
print(f"The average temperature at '{active_stationName}' is {av_temp} degrees Farenheit.")
# Out:
# The average temperature at 'WAIHEE 837.5, HI US' is 71.7 degrees Farenheit.

# %%
# Using the most active station id
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram

# Get the last 12 months of temperature data for Waihee
temp_data = (session.query(Measurement.date, Measurement.tobs)
                   .filter(Measurement.date >= prev_year)
                   .filter(Measurement.station == active_station_ID)
                   .order_by(Measurement.date)
                   .all())

# Save the temp_data as a Pandas DataFrame
temp_data_table_df = pd.DataFrame(temp_data)
temp_data_table_df

# Set date to index
temp_data_table_df = temp_data_table_df.set_index('date')

# Sort the dataframe by date and rename 'tobs' column to 'temperature'
temp_by_date_df = temp_data_table_df.sort_index(ascending=True)
temp_by_date_df = temp_by_date_df.rename(columns={'tobs' : 'temperature'})
temp_by_date_df
# Out:
#             temperature
# date
# 2016-08-23         77.0
# 2016-08-24         77.0
# 2016-08-25         80.0
# 2016-08-26         80.0
# 2016-08-27         75.0
# ...                 ...
# 2017-08-14         77.0
# 2017-08-15         77.0
# 2017-08-16         76.0
# 2017-08-17         76.0
# 2017-08-18         79.0
#
# [352 rows x 1 columns]

# %%
# Plot the results as a histogram with 12 bins
temp_by_date_df.plot(kind='hist', bins=12);

# %% [markdown]
# # Close session

# %%
# Close Session
session.close()
